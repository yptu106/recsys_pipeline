# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/nas02/home/kevin/recsys_pipeline/data/raw/top100_streamers.csv")
df = df.rename(columns={"pfid": "streamer_id"})

df.to_parquet("/nas02/home/kevin/recsys_pipeline/data/processed/top100_streamers.parquet", index=False)

# %%
df.head()
# Out:
#       nickname        dt  streamer_id  sno
# 0  安心啞💋⁵⁹⁸⁷⁹⁰²  2025/6/1      5987902    1
# 1      Mina❄☃️  2025/6/1      5259232    2
# 2         柔柔🤍✨  2025/6/1      5788978    3
# 3         🧚蓉蓉🤍  2025/6/1      5113035    4
# 4     🎙佐菈Zora♡  2025/6/1      6159862    5
